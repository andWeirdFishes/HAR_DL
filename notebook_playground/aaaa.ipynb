# %%
import pandas as pd
from emteqai.utils.plots.plots import plot_data

df = pd.read_csv('/home/bojan/Desktop/HAR_DL/data/preprocessed/HAR_DL_FEIT_2025/P03_BojanD/task1_ea_P03_BojanD_PROCESSED.csv')

plot_data(df=df,cols=['Pressure/Raw.Deriv'],col_label='Label')
# Out:
# (<Figure size 1800x1000 with 1 Axes>, <Axes: >)
